# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 6244-3268
#
#  Directory of C:\Users\91984
#
# 03-07-2022  10:24    <DIR>          .
# 03-07-2022  10:24    <DIR>          ..
# 09-04-2022  04:59    <DIR>          .anaconda
# 22-06-2022  23:33               855 .bash_history
# 04-07-2022  20:09    <DIR>          .conda
# 06-04-2022  23:24                25 .condarc
# 06-04-2022  23:23    <DIR>          .continuum
# 07-04-2022  09:59               163 .gitconfig
# 03-07-2022  10:18    <DIR>          .ipynb_checkpoints
# 06-04-2022  23:27    <DIR>          .ipython
# 08-04-2022  14:19    <DIR>          .jupyter
# 17-04-2022  15:05    <DIR>          .matplotlib
# 25-06-2022  10:56                32 .node_repl_history
# 24-01-2022  20:14    <DIR>          .vscode
# 13-11-2021  16:43    <DIR>          3D Objects
# 09-04-2022  05:04    <DIR>          anaconda3
# 23-07-2020  18:41        54,342,959 application_record.csv
# 13-11-2021  16:43    <DIR>          Contacts
# ...

# %%
df=pd.read_csv('dm_office_sales.csv')

# %%
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
sns.scatterplot(x='salary', y='sales', data=df);

# %%
sns.scatterplot(x='salary', y='sales', data=df, hue='level of education');

# %%
sns.scatterplot(x='salary', y='sales', data=df, hue='salary');

# %%
sns.scatterplot(x='salary', y='sales', data=df, hue='level of education',palette='Dark2');

# %%
sns.scatterplot(x='salary', y='sales', data=df, s=100, alpha=0.2);

# %%
sns.scatterplot(x='salary', y='sales', data=df, style='level of education');

# %%
sns.scatterplot(x='salary', y='sales', data=df, hue='level of education', style='level of education');

# %%
##distribution plots ahead

# %%
sns.rugplot(x='salary', data=df, height=0.5);

# %%
sns.displot(x='salary', data=df);

# %%
sns.set(style='darkgrid')
sns.displot(x='salary', data=df);
#whitegrid, white, dark, ticks

# %%
sns.kdeplot(x='salary', data=df);

# %%
np.random.seed(42)
sample = np.random.randint(0,100,200)

# %% [markdown]
# sample

# %%
sample
# Out:
# array([51, 92, 14, 71, 60, 20, 82, 86, 74, 74, 87, 99, 23,  2, 21, 52,  1,
#        87, 29, 37,  1, 63, 59, 20, 32, 75, 57, 21, 88, 48, 90, 58, 41, 91,
#        59, 79, 14, 61, 61, 46, 61, 50, 54, 63,  2, 50,  6, 20, 72, 38, 17,
#         3, 88, 59, 13,  8, 89, 52,  1, 83, 91, 59, 70, 43,  7, 46, 34, 77,
#        80, 35, 49,  3,  1,  5, 53,  3, 53, 92, 62, 17, 89, 43, 33, 73, 61,
#        99, 13, 94, 47, 14, 71, 77, 86, 61, 39, 84, 79, 81, 52, 23, 25, 88,
#        59, 40, 28, 14, 44, 64, 88, 70,  8, 87,  0,  7, 87, 62, 10, 80,  7,
#        34, 34, 32,  4, 40, 27,  6, 72, 71, 11, 33, 32, 47, 22, 61, 87, 36,
#        98, 43, 85, 90, 34, 64, 98, 46, 77,  2,  0,  4, 89, 13, 26,  8, 78,
#        14, 89, 41, 76, 50, 62, 95, 51, 95,  3, 93, 22, 14, 42, 28, 35, 12,
#        31, 70, 58, 85, 27, 65, 41, 44, 61, 56,  5, 27, 27, 43, 83, 29, 61,
#        74, 91, 88, 61, 96,  0, 26, 61, 76,  2, 69, 71, 26])

# %%
sample = pd.DataFrame(sample, columns=['age'])

# %%
sample
# Out:
#      age
# 0     51
# 1     92
# 2     14
# 3     71
# 4     60
# ..   ...
# 195   76
# 196    2
# 197   69
# 198   71
# 199   26
#
# [200 rows x 1 columns]

# %%
sns.rugplot(x='age', data=sample);

# %%
sns.kdeplot(x='age', data=sample);

# %%
sns.displot(x='age', data=sample, kde=True);

# %%
sns.kdeplot(x='age', data=sample, clip=[0,100]);

# %%
sns.kdeplot(x='age', data=sample, clip=[0,100], bw_adjust=0.1);

# %%
#categorical plots ahead

# %%
df['division'].value_counts()
# Out:
# office supplies      252
# printers             250
# peripherals          243
# computer hardware    159
# computer software     96
# Name: division, dtype: int64

# %%
sns.set(style='white')
plt.figure(figsize=(10,5))
sns.countplot(data=df, x='division');

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df, x='division', hue='level of education');

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=df, x='level of education', y='salary', estimator=np.mean, ci='sd',palette='summer');

# %%
##categorical plots ahead

# %%
df = pd.read_csv("StudentsPerformance.csv")

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
sns.boxplot(data=df,y='math score',x='test preparation course');

# %%
sns.boxplot(data=df,y='reading score',x='test preparation course');

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df,y='math score',x='parental level of education',hue='test preparation course');

# %%
sns.violinplot(data=df,y='reading score',x='test preparation course');

# %%
sns.swarmplot(data=df,y='reading score',x='test preparation course');
# Out:
# C:\Users\91984\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 16.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(data=df,y='gender',x='math score');
# Out:
# C:\Users\91984\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 16.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\91984\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 15.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(data=df,y='gender',x='math score', size=2);

# %%
sns.swarmplot(data=df,y='gender',x='math score', size=2, hue='test preparation course', dodge=True);

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sns.jointplot(data=df, x='math score', y='reading score');

# %%
sns.jointplot(data=df, x='math score', y='reading score', kind='hex');
#maybe try alpha

# %%
sns.jointplot(data=df, x='math score', y='reading score', kind='hist');
#lines up w the bars on the right

# %%
sns.jointplot(data=df, x='math score', y='reading score', kind='kde');

# %%
sns.jointplot(data=df, x='math score', y='reading score', kind='kde', shade=True);

# %%
sns.jointplot(data=df, x='math score', y='reading score', hue='gender');

# %%
sns.pairplot(df, hue='gender')

# %%
##grid plot ahead

# %%
sns.catplot(data=df, x='gender', y='math score', kind='box', row='lunch');
